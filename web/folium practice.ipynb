# %%
import folium

# Create a map centered at a specific location
map_center = [37.26798051271562, 127.00475536610438]  # Coordinates for New York City
my_map = folium.Map(location=map_center, zoom_start=12)

# Define coordinates for a line
line_coordinates = [[37.26798051271562, 127.00475536610438],
 [37.26785031225609, 127.00444130687885],
 [37.26772990902032, 127.004121711203],
 [37.2676195964245, 127.00382909621204],
 [37.267598910273485, 127.00377423566552],
 [37.26758128665887, 127.0037274575307],
 [37.2675348694428, 127.003604264817],
 [37.267510794547725, 127.00354051888334],
 [37.26750786717307, 127.0035328642124],
 [37.267583970224486, 127.00346672139123],
 [37.26759446794046, 127.00346029589228],
 [37.26763160911968, 127.00343755813888],
 [37.26767262498665, 127.00341279185255],
 [37.26775444196496, 127.0033636395679],
 [37.26792221863015, 127.0032606020484],
 [37.26797754353242, 127.00322475173162],
 [37.26805620575082, 127.00318337943185],
 [37.26810138329682, 127.00316183601072],
 [37.26810686191354, 127.00315323279952],
 [37.26813157033291, 127.00311443902442],
 [37.26813099426838, 127.00311291794432],
 [37.26812400250359, 127.00309474445407],
 [37.26800873081891, 127.0027950949084],
 [37.267875744497296, 127.00244017836712],
 [37.267777175480646, 127.00217861447824],
 [37.26763933214544, 127.00180692712053],
 [37.267616076367545, 127.00175041933998],
 [37.26759463271102, 127.00169742080377],
 [37.2674472987848, 127.0013113681127],
 [37.26765197532561, 127.00186192362693]]
# Create a PolyLine object with the line coordinates and add it to the map
folium.PolyLine(locations=line_coordinates, color='blue').add_to(my_map)

# Save the map as an HTML file
my_map.save('./map_with_line.html')
